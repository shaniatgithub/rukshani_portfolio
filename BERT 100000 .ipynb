# %%
import pandas as pd
import numpy as np
df1 = pd.read_csv("AMAZON_FASHION.json.gz",sep='\t',header=0)
df1
# Out:
#        {"overall": 5.0, "verified": true, "reviewTime": "10 20, 2014", "reviewerID": "A1D4G1SNUZWQOT", "asin": "7106116521", "reviewerName": "Tracy", "reviewText": "Exactly what I needed.", "summary": "perfect replacements!!", "unixReviewTime": 1413763200}
# 0       {"overall": 2.0, "vote": "3", "verified": true...
# 1       {"overall": 4.0, "verified": false, "reviewTim...
# 2       {"overall": 2.0, "verified": true, "reviewTime...
# 3       {"overall": 3.0, "verified": false, "reviewTim...
# 4       {"overall": 5.0, "verified": true, "reviewTime...
# ...                                                   ...
# 883630  {"overall": 5.0, "verified": true, "reviewTime...
# 883631  {"overall": 5.0, "vote": "2", "verified": true...
# 883632  {"overall": 3.0, "verified": true, "reviewTime...
# 883633  {"overall": 3.0, "verified": true, "reviewTime...
# 883634  {"overall": 5.0, "verified": true, "reviewTime...
#
# [883635 rows x 1 columns]

# %%
import pandas as pd
import gzip
import json

def parse(path):
  g = gzip.open(path, 'rt', encoding='utf-8')
  for l in g:
    yield json.loads(l)

def getDF(path):
  i = 0
  df = {}
  for d in parse(path):
    df[i] = d
    i += 1
  return pd.DataFrame.from_dict(df, orient='index')

df = getDF('AMAZON_FASHION.json.gz')
df
# Out:
#         overall  verified   reviewTime      reviewerID        asin  \
# 0           5.0      True  10 20, 2014  A1D4G1SNUZWQOT  7106116521
# 1           2.0      True  09 28, 2014  A3DDWDH9PX2YX2  7106116521
# 2           4.0     False  08 25, 2014  A2MWC41EW7XL15  7106116521
# 3           2.0      True  08 24, 2014  A2UH2QQ275NV45  7106116521
# 4           3.0     False  07 27, 2014   A89F3LQADZBS5  7106116521
# ...         ...       ...          ...             ...         ...
# 883631      5.0      True  02 21, 2017  A1ZSB2Q144UTEY  B01HJHTH5U
# 883632      5.0      True  11 25, 2016  A2CCDV0J5VB6F2  B01HJHTH5U
# 883633      3.0      True  11 10, 2016  A3O90PACS7B61K  B01HJHTH5U
# 883634      3.0      True  11 10, 2016  A2HO94I89U3LNH  B01HJHF97K
# 883635      5.0      True   08 9, 2016  A2RSX9E79DUHRX  B01HJG5NMW
#
#                reviewerName  \
# 0                     Tracy
# 1                 Sonja Lau
# 2                  Kathleen
# 3               Jodi Stoner
# 4              Alexander D.
# ...                     ...
# 883631      Amazon Customer
# 883632      Amazon Customer
# 883633             Fabfifty
# 883634               Mgomez
# 883635  Natasha Mascarenhas
#
#                                                reviewText  \
# 0                                  Exactly what I needed.
# 1       I agree with the other review, the opening is ...
# 2       Love these... I am going to order another pack...
# 3                                     too tiny an opening
# 4                                                    Okay
# ...                                                   ...
# 883631  I absolutely love this dress!!  It's sexy and ...
# 883632  I'm 5'6 175lbs. I'm on the tall side. I wear a...
# 883633                         Too big in the chest area!
# 883634                Too clear in the back, needs lining
# 883635  Ordered and was slightly small. Worked with th...
#
#                                                   summary  unixReviewTime  \
# 0                                  perfect replacements!!      1413763200
# 1       I agree with the other review, the opening is ...      1411862400
# 2                                     My New 'Friends' !!      1408924800
# 3                                               Two Stars      1408838400
# 4                                             Three Stars      1406419200
# ...                                                   ...             ...
# 883631                       I absolutely love this dress      1487635200
# 883632  I wear a large and ordered a large and it stil...      1480032000
# 883633                                        Three Stars      1478736000
# 883634                                        Three Stars      1478736000
# 883635         The quality is excellent and it is so cute      1470700800
#
#        vote style image
# 0       NaN   NaN   NaN
# 1         3   NaN   NaN
# 2       NaN   NaN   NaN
# 3       NaN   NaN   NaN
# 4       NaN   NaN   NaN
# ...     ...   ...   ...
# 883631  NaN   NaN   NaN
# 883632    2   NaN   NaN
# 883633  NaN   NaN   NaN
# 883634  NaN   NaN   NaN
# 883635  NaN   NaN   NaN
#
# [883636 rows x 12 columns]

# %%
newdf = df.sample(n=100000, random_state=42) #getting a sample data of 1000 from the existing data set with the random state 42 to unsure the reproducibility
newdf   #new data set with 1000 random rows is called as newdf
# Out:
#         overall  verified   reviewTime      reviewerID        asin  \
# 87569       2.0     False  08 24, 2014   AWIYG7HFJJEIB  B007XD6K1U
# 691612      1.0      True  06 14, 2016   A8Q2DT85Q8CAN  B01423Q1E4
# 204341      1.0      True  04 30, 2016   ANAE9TUXKTR6X  B00LWZH8C0
# 625152      2.0      True  03 28, 2016  A2JK19L9NH65JB  B00VPQXYW4
# 457145      5.0      True  10 11, 2016  A29VT82OW77PZ7  B00D7UX1YM
# ...         ...       ...          ...             ...         ...
# 176319      5.0     False   09 8, 2014   ATLFN1TCTXS0W  B00IYF4QSA
# 423704      5.0      True  11 20, 2013  A2S2UOIHS3DK1C  B006CUTR9W
# 721061      5.0      True  06 12, 2018  A10PEN6JLSUV7L  B016AZORSY
# 30975       4.0      True  10 22, 2017  A331OW361SGRSB  B000YFSR5G
# 849081      5.0      True  04 26, 2017   A10NISFP0DG2V  B01F4SIBKS
#
#                 reviewerName  \
# 87569                 osiris
# 691612              Waistin$
# 204341        peter politano
# 625152       Amazon Customer
# 457145  Apostle Arthur Young
# ...                      ...
# 176319                     B
# 423704                  Kurt
# 721061       Tiffany Stewart
# 30975       Michael  W Young
# 849081                     S
#
#                                                reviewText  \
# 87569                              nut Malo es very cheap
# 691612  It seems the sizing of this is way off.  I rea...
# 204341  they are too small they did not even fit on my...
# 625152  I thought I got the right size but apparently ...
# 457145                                 I love this wallet
# ...                                                   ...
# 176319  This is soo cute and really original. It reall...
# 423704  This ring is a great buy!  I've gotten nothing...
# 721061                                      Great Jacket!
# 30975                                           Love them
# 849081  This is just perfect and well made too. I want...
#
#                                                   summary  unixReviewTime  \
# 87569                                           Two Stars      1408838400
# 691612                                Entirely too small!      1465862400
# 204341  ... not even fit on my ear i would not recomme...      1461974400
# 625152  I thought I got the right size but apparently ...      1459123200
# 457145                                         Five Stars      1476144000
# ...                                                   ...             ...
# 176319                                     love love love      1410134400
# 423704                       Great ring for a great price      1384905600
# 721061                                         Five Stars      1528761600
# 30975                                          Four Stars      1508630400
# 849081                                           So cute!      1493164800
#
#        vote                                          style image
# 87569   NaN                                            NaN   NaN
# 691612  NaN                                            NaN   NaN
# 204341  NaN     {'Color:': ' #M01. 2 Pairs: Steel + Gold'}   NaN
# 625152  NaN                                            NaN   NaN
# 457145  NaN                                            NaN   NaN
# ...     ...                                            ...   ...
# 176319  NaN                                            NaN   NaN
# 423704    2                               {'Size:': ' 11'}   NaN
# 721061  NaN                                            NaN   NaN
# 30975   NaN  {'Size:': ' Medium', 'Color:': ' Deep Royal'}   NaN
# 849081  NaN                                            NaN   NaN
#
# [100000 rows x 12 columns]

# %%
new_df = newdf.dropna(subset=['reviewText']).reset_index(drop=True) #dropping missing or null values (will be missing 2 rows)

# %%
my_columns = ['overall', 'verified', 'reviewerID', 'reviewText', 'summary']

# Create a new DataFrame 'mydf' with only the selected columns
mydf = new_df.loc[:, my_columns]
mydf
# Out:
#        overall  verified      reviewerID  \
# 0          2.0     False   AWIYG7HFJJEIB
# 1          1.0      True   A8Q2DT85Q8CAN
# 2          1.0      True   ANAE9TUXKTR6X
# 3          2.0      True  A2JK19L9NH65JB
# 4          5.0      True  A29VT82OW77PZ7
# ...        ...       ...             ...
# 99875      5.0     False   ATLFN1TCTXS0W
# 99876      5.0      True  A2S2UOIHS3DK1C
# 99877      5.0      True  A10PEN6JLSUV7L
# 99878      4.0      True  A331OW361SGRSB
# 99879      5.0      True   A10NISFP0DG2V
#
#                                               reviewText  \
# 0                                 nut Malo es very cheap
# 1      It seems the sizing of this is way off.  I rea...
# 2      they are too small they did not even fit on my...
# 3      I thought I got the right size but apparently ...
# 4                                     I love this wallet
# ...                                                  ...
# 99875  This is soo cute and really original. It reall...
# 99876  This ring is a great buy!  I've gotten nothing...
# 99877                                      Great Jacket!
# 99878                                          Love them
# 99879  This is just perfect and well made too. I want...
#
#                                                  summary
# 0                                              Two Stars
# 1                                    Entirely too small!
# 2      ... not even fit on my ear i would not recomme...
# 3      I thought I got the right size but apparently ...
# 4                                             Five Stars
# ...                                                  ...
# 99875                                     love love love
# 99876                       Great ring for a great price
# 99877                                         Five Stars
# 99878                                         Four Stars
# 99879                                           So cute!
#
# [99880 rows x 5 columns]

# %%
def cal_sentiment(overall):                #function to determine the sentiment
    if overall > 3:
        return 'Positive'
    elif overall     == 3:
        return 'Neutral'
    else:
        return 'Negative'

mydf['Sentiment of Star Ratings'] = mydf['overall'].apply(cal_sentiment)        # Apply the function to create the 'Star Ratings' column
mydf
# Out:
#        overall  verified      reviewerID  \
# 0          2.0     False   AWIYG7HFJJEIB
# 1          1.0      True   A8Q2DT85Q8CAN
# 2          1.0      True   ANAE9TUXKTR6X
# 3          2.0      True  A2JK19L9NH65JB
# 4          5.0      True  A29VT82OW77PZ7
# ...        ...       ...             ...
# 99875      5.0     False   ATLFN1TCTXS0W
# 99876      5.0      True  A2S2UOIHS3DK1C
# 99877      5.0      True  A10PEN6JLSUV7L
# 99878      4.0      True  A331OW361SGRSB
# 99879      5.0      True   A10NISFP0DG2V
#
#                                               reviewText  \
# 0                                 nut Malo es very cheap
# 1      It seems the sizing of this is way off.  I rea...
# 2      they are too small they did not even fit on my...
# 3      I thought I got the right size but apparently ...
# 4                                     I love this wallet
# ...                                                  ...
# 99875  This is soo cute and really original. It reall...
# 99876  This ring is a great buy!  I've gotten nothing...
# 99877                                      Great Jacket!
# 99878                                          Love them
# 99879  This is just perfect and well made too. I want...
#
#                                                  summary  \
# 0                                              Two Stars
# 1                                    Entirely too small!
# 2      ... not even fit on my ear i would not recomme...
# 3      I thought I got the right size but apparently ...
# 4                                             Five Stars
# ...                                                  ...
# 99875                                     love love love
# 99876                       Great ring for a great price
# 99877                                         Five Stars
# 99878                                         Four Stars
# 99879                                           So cute!
#
#       Sentiment of Star Ratings
# 0                      Negative
# 1                      Negative
# 2                      Negative
# 3                      Negative
# 4                      Positive
# ...                         ...
# 99875                  Positive
# 99876                  Positive
# 99877                  Positive
# 99878                  Positive
# 99879                  Positive
#
# [99880 rows x 6 columns]

# %%
pip install transformers
# Out:
# Requirement already satisfied: transformers in c:\apps\ana\lib\site-packages (4.33.2)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: safetensors>=0.3.1 in c:\apps\ana\lib\site-packages (from transformers) (0.3.3)
# Requirement already satisfied: tqdm>=4.27 in c:\apps\ana\lib\site-packages (from transformers) (4.64.0)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in c:\apps\ana\lib\site-packages (from transformers) (0.13.3)
# Requirement already satisfied: regex!=2019.12.17 in c:\apps\ana\lib\site-packages (from transformers) (2022.3.15)
# Requirement already satisfied: pyyaml>=5.1 in c:\apps\ana\lib\site-packages (from transformers) (6.0)
# Requirement already satisfied: packaging>=20.0 in c:\apps\ana\lib\site-packages (from transformers) (21.3)
# Requirement already satisfied: numpy>=1.17 in c:\apps\ana\lib\site-packages (from transformers) (1.21.5)
# Requirement already satisfied: filelock in c:\apps\ana\lib\site-packages (from transformers) (3.6.0)
# Requirement already satisfied: requests in c:\apps\ana\lib\site-packages (from transformers) (2.27.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.15.1 in c:\apps\ana\lib\site-packages (from transformers) (0.17.1)
# Requirement already satisfied: fsspec in c:\apps\ana\lib\site-packages (from huggingface-hub<1.0,>=0.15.1->transformers) (2022.2.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\apps\ana\lib\site-packages (from huggingface-hub<1.0,>=0.15.1->transformers) (4.8.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\apps\ana\lib\site-packages (from packaging>=20.0->transformers) (3.0.4)
# Requirement already satisfied: colorama in c:\apps\ana\lib\site-packages (from tqdm>=4.27->transformers) (0.4.6)
# Requirement already satisfied: idna<4,>=2.5 in c:\apps\ana\lib\site-packages (from requests->transformers) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\apps\ana\lib\site-packages (from requests->transformers) (1.26.9)
# Requirement already satisfied: certifi>=2017.4.17 in c:\apps\ana\lib\site-packages (from requests->transformers) (2021.10.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\apps\ana\lib\site-packages (from requests->transformers) (2.0.4)

# %%
# !pip install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu118
# Out:
# Looking in indexes: https://download.pytorch.org/whl/cu118
# Requirement already satisfied: torch in c:\apps\ana\lib\site-packages (2.0.1+cu118)
# Requirement already satisfied: torchvision in c:\apps\ana\lib\site-packages (0.15.2+cu118)
# Requirement already satisfied: torchaudio in c:\apps\ana\lib\site-packages (2.0.2+cu118)
# Requirement already satisfied: networkx in c:\apps\ana\lib\site-packages (from torch) (2.7.1)
# Requirement already satisfied: jinja2 in c:\apps\ana\lib\site-packages (from torch) (2.11.3)
# Requirement already satisfied: typing-extensions in c:\apps\ana\lib\site-packages (from torch) (4.8.0)
# Requirement already satisfied: filelock in c:\apps\ana\lib\site-packages (from torch) (3.6.0)
# Requirement already satisfied: sympy in c:\apps\ana\lib\site-packages (from torch) (1.10.1)
# Requirement already satisfied: requests in c:\apps\ana\lib\site-packages (from torchvision) (2.27.1)
# Requirement already satisfied: numpy in c:\apps\ana\lib\site-packages (from torchvision) (1.21.5)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in c:\apps\ana\lib\site-packages (from torchvision) (9.0.1)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\apps\ana\lib\site-packages (from jinja2->torch) (2.0.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\apps\ana\lib\site-packages (from requests->torchvision) (2021.10.8)
# Requirement already satisfied: idna<4,>=2.5 in c:\apps\ana\lib\site-packages (from requests->torchvision) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\apps\ana\lib\site-packages (from requests->torchvision) (1.26.9)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\apps\ana\lib\site-packages (from requests->torchvision) (2.0.4)
# Requirement already satisfied: mpmath>=0.19 in c:\apps\ana\lib\site-packages (from sympy->torch) (1.2.1)

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix
import torch
from transformers import AutoTokenizer, AutoModelForSequenceClassification
import torch
import requests
import re

# Load your data into a DataFrame (replace this with your actual data loading)
# Assuming you have a DataFrame named 'mydf' with 'CleanedText' and 'Overall' columns

# Split the data into training and testing sets
train_df, test_df = train_test_split(mydf, test_size=0.2, random_state=42)

# Load the pretrained BERT model and tokenizer
tokenizer = AutoTokenizer.from_pretrained('LiYuan/amazon-review-sentiment-analysis')
my_model = AutoModelForSequenceClassification.from_pretrained('LiYuan/amazon-review-sentiment-analysis')

# Function to calculate sentiment score
def sentiment_score(review):
    tokens = tokenizer.encode(review, return_tensors='pt',truncation=True, padding=True)
    result = my_model(tokens)
    return int(torch.argmax(result.logits)) + 1

# Apply the sentiment_score function to the testing set
test_df['Predicted Rating'] = test_df['reviewText'].apply(lambda x: sentiment_score(x[:512]))

# %%
def cal_sentiment(Overall):                #function to determine the sentiment
    if Overall > 3:
        return 'Positive'
    elif Overall     == 3:
        return 'Neutral'
    else:
        return 'Negative'

test_df['Sentiment of Predicted Ratings'] = test_df['Predicted Rating'].apply(cal_sentiment)        # Apply the function to create the 'Star Ratings' columntest_df

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use ('ggplot')
from sklearn.metrics import confusion_matrix
import numpy as np

# Define a mapping from string labels to numerical labels
label_mapping = {"Negative": 0, "Neutral": 1, "Positive": 2}

# Convert the actual and predicted labels to numerical values
y_true = np.array([label_mapping[label] for label in test_df['Sentiment of Star Ratings']])
y_pred = np.array([label_mapping[label] for label in test_df['Sentiment of Predicted Ratings']])

# Calculate the confusion matrix
conf_matrix = confusion_matrix(y_true, y_pred)

# Create a heatmap to visualize the confusion matrix
classes = list(label_mapping.keys())
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Greens', cbar=False,
            xticklabels=classes, yticklabels=classes)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()

# %%
# Evaluate the model on the test set
y_true = test_df['Sentiment of Star Ratings']  # Actual ratings
y_pred = test_df['Sentiment of Predicted Ratings']  # Predicted ratings

# Calculate the confusion matrix
conf_matrix = confusion_matrix(y_true, y_pred)

# Generate a classification report
report = classification_report(y_true, y_pred)

# Print the confusion matrix and classification report
print("Confusion Matrix:")
print(conf_matrix)
print("\nClassification Report:")
print(report)
# Out:
# Confusion Matrix:
# [[ 2886   585   432]
#  [  486   781   891]
#  [  183   484 13248]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#     Negative       0.81      0.74      0.77      3903
#      Neutral       0.42      0.36      0.39      2158
#     Positive       0.91      0.95      0.93     13915
#
#     accuracy                           0.85     19976
#    macro avg       0.71      0.68      0.70     19976
# weighted avg       0.84      0.85      0.84     19976
